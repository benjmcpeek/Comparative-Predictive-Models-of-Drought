# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
soil_df = pd.read_csv('../data/output_csv_files/soil_df.csv', parse_dates = True)
soil_df.head()
# Out:
#             soil_moisture
# 1958-01-01   21782.091367
# 1958-02-01   21782.160837
# 1958-03-01   21782.054664
# 1958-04-01   21782.649686
# 1958-05-01   21782.306092

# %%
soil_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 780 entries, 1958-01-01 to 2022-12-01
# Data columns (total 1 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   soil_moisture  780 non-null    float64
# dtypes: float64(1)
# memory usage: 12.2 KB

# %%
soil_df.describe()
# Out:
#        soil_moisture
# count     780.000000
# mean    21781.774901
# std         0.723065
# min     21779.936546
# 25%     21781.217736
# 50%     21781.857011
# 75%     21782.363770
# max     21783.378717

# %% [markdown]
# I have not been able to find what units these soil moisture data are in, so making specific interpretations of this data will be difficult.

# %%
plt.figure(figsize = (12, 6), dpi = 200)
sns.lineplot(soil_df)
plt.xticks(rotation = 45);
plt.ylabel('Soil Moisture (mm)')
plt.title('American Soil Moisture 1958-2023');

# %% [markdown]
# The above plot clearly shows a high degree of seasonality. It is difficult to determine exactly, but there appears to be a minor downward trend as well.

# %%
plt.figure(figsize = (12, 6), dpi = 200)
sns.lineplot(soil_df.loc['2010':])
plt.xticks(rotation = 45);
plt.ylabel('Soil Moisture (mm)')
plt.title('American Soil Moisture From 2010-2023');

# %% [markdown]
# Zooming in to just 2010-2023, the periodicity is clearly yearly. Around the start of each year, soil moisture peaks and tends to bottom out towards the middle of the year i.e. summer.
